# %%
# pip install statsmodels

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# %%
word_df = pd.read_csv("webpage/data_for_plotting.csv")
word_cleaned = word_df.dropna(axis='columns', how='all')
word_cleaned
# Out:
#        Review_ID  Rating     Reviewer_Location  \
# 0      670772142       4             Australia
# 1      670682799       4           Philippines
# 2      670623270       4  United Arab Emirates
# 3      670607911       4             Australia
# 4      670607296       4        United Kingdom
# ...          ...     ...                   ...
# 40038   92198076       4        United Kingdom
# 40039   92061774       4               Germany
# 40040   91995748       1        United Kingdom
# 40041   91984642       2        United Kingdom
# 40042   91827418       5        United Kingdom
#
#                                              Review_Text               Branch  \
# 0      If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1      Its been a while since d last time we visit HK...  Disneyland_HongKong
# 2      Thanks God it wasn   t too hot or too humid wh...  Disneyland_HongKong
# 3      HK Disneyland is a great compact park. Unfortu...  Disneyland_HongKong
# ...

# %%
word_working = word_cleaned.dropna()
word_working
# Out:
#        Review_ID  Rating     Reviewer_Location  \
# 0      670772142       4             Australia
# 1      670682799       4           Philippines
# 2      670623270       4  United Arab Emirates
# 3      670607911       4             Australia
# 4      670607296       4        United Kingdom
# ...          ...     ...                   ...
# 40038   92198076       4        United Kingdom
# 40039   92061774       4               Germany
# 40040   91995748       1        United Kingdom
# 40041   91984642       2        United Kingdom
# 40042   91827418       5        United Kingdom
#
#                                              Review_Text               Branch  \
# 0      If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1      Its been a while since d last time we visit HK...  Disneyland_HongKong
# 2      Thanks God it wasn   t too hot or too humid wh...  Disneyland_HongKong
# 3      HK Disneyland is a great compact park. Unfortu...  Disneyland_HongKong
# ...

# %%
label = "is_good_review"
ignore_cols = [label, "Review_Text", "review_clean", "Reviewer_Location","Branch","Rating", ""]
all_predictors = [c for c in word_working.columns if c not in ignore_cols]
all_predictors
# Out:
# ['Review_ID',
#  'Year',
#  'Month',
#  'neg',
#  'pos',
#  'neu',
#  'compound',
#  'characters',
#  'words',
#  'word_money',
#  'word_hour',
#  'word_disappointed',
#  'word_great',
#  'word_close',
#  'word_love',
#  'word_poor',
#  'word_pay',
#  'word_people',
#  'word_waste']

# %%
X_train, X_test, y_train, y_test = train_test_split(reviews_df[all_predictors], reviews_df["is_good_review"], test_size = 0.20, random_state = 42)
X_train

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
from sklearn.feature_selection import RFE
rfe = RFE(logreg, 15)             
rfe = rfe.fit(X_train, y_train)

# %%
metrics.accuracy_score(y_pred_final['Converted'], y_pred_final.final_predicted)

TP = confusion2[1,1]
TN = confusion2[0,0] 
FP = confusion2[0,1] 
FN = confusion2[1,0] 

TP/(TP+FP)
TP/(TP+FN)
